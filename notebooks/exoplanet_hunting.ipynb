# %% [markdown]
# # Exoplanet Hunting with NASA Data
#
# In this notebook, we explore confirmed exoplanets from NASA's Exoplanet Archive.
#
# ## Goals
# 1. Load and explore the exoplanet dataset
# 2. Find potentially habitable planets
# 3. Visualize exoplanet discovery trends over time
# 4. Compare exoplanet sizes and temperatures

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('dark_background')

# Load dataset
# df = pd.read_csv('../datasets/exoplanets/exoplanets.csv')
# For now, let's create a sample
print('Exoplanet Hunting Notebook Ready')
print('Load the NASA Exoplanet Archive CSV to begin analysis.')

# %% [markdown]
# ## 1. Dataset Overview
#
# The NASA Exoplanet Archive contains 5,000+ confirmed exoplanets.
# Key columns include planet radius, mass, equilibrium temperature,
# orbital period, and host star properties.

# %%
# df = pd.read_csv('../datasets/exoplanets/exoplanets.csv')
# print(f'Total confirmed exoplanets: {len(df):,}')
# df.head()

# %% [markdown]
# ## 2. Finding Habitable Planets
#
# We define 'potentially habitable' as:
# - Radius < 2 Earth radii (likely rocky)
# - Equilibrium temperature: 200-320 K (liquid water possible)
# - Host star temperature < 6,000 K (stable, long-lived)

# %%
# habitable = df[
#     (df['pl_rade'] < 2.0) &
#     (df['pl_eqt'] > 200) &
#     (df['pl_eqt'] < 320) &
#     (df['st_teff'] < 6000)
# ]
# print(f'Potentially habitable planets: {len(habitable)}')
# habitable[['pl_name', 'hostname', 'pl_rade', 'pl_eqt', 'sy_dist']].head(20)

# %% [markdown]
# ## 3. Discovery Trends
#
# Let's visualize how exoplanet discoveries have accelerated over time,
# driven by missions like Kepler (2009-2018) and TESS (2018-present).

# %%
# df['disc_year'].value_counts().sort_index().plot(
#     kind='bar', figsize=(14, 5), color='dodgerblue',
#     title='Exoplanet Discoveries per Year'
# )
# plt.xlabel('Year'); plt.ylabel('Number of Discoveries')
# plt.tight_layout(); plt.show()
